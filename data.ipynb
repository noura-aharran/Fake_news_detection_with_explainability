# %% [markdown]
# ### WELFake_Dataset

# %%
from datasets import load_dataset
import numpy as np
# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("Summitsky/WELFake_Dataset_Edited")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: Le module spécifié est introuvable.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from datasets import load_dataset
#       2 import numpy as np
#       3 # Login using e.g. `huggingface-cli login` to access this dataset
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\datasets\__init__.py:24
#      20 __version__ = "2.12.0"
#      22 import platform
# ---> 24 import pyarrow
#      25 from packaging import version
#      28 if version.parse(platform.python_version()) < version.parse("3.7"):
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\pyarrow\__init__.py:65
#      63 _gc_enabled = _gc.isenabled()
#      64 _gc.disable()
# ---> 65 import pyarrow.lib as _lib
#      66 if _gc_enabled:
#      67     _gc.enable()
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\pyarrow\lib.pyx:41, in init pyarrow.lib()
#
# ImportError: numpy._core.multiarray failed to import

# %% [markdown]
# ### FakeNewaNet

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("rickstello/FakeNewsNet")

# %% [markdown]
# ### COVID_fake_news

# %%
from datasets import load_dataset

ds = load_dataset("nanyy1025/covid_fake_news")
